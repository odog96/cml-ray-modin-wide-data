# %% [markdown]
# #### Reading with pandas

# %% [markdown]
# #### Reading with Modin Pandas

# %%
start = time.time()

modin_df = pd.read_csv(dataset_url, parse_dates=["tpep_pickup_datetime", "tpep_dropoff_datetime"], quoting=3)

end = time.time()
modin_duration = end - start
print("Time to read with Modin: {} seconds".format(round(modin_duration, 3)))

print("Modin is {}x faster than pandas at `read_csv`!".format(round(pandas_duration / modin_duration, 2)))
# Out:
# Time to read with Modin: 4.614 seconds
# Modin is 1.05x faster than pandas at `read_csv`!

# %%
modin_df.shape
# Out:
# (1933507, 21)

# %%
modin_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  VendorID tpep_pickup_datetime  \
# 0             0           0         1  2015-01-01 00:11:33
# 1             1           1         1  2015-01-01 00:18:24
# 2             2           2         1  2015-01-01 00:26:19
# 3             3           3         1  2015-01-01 00:45:26
# 4             4           4         1  2015-01-01 00:59:21
#
#   tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0   2015-01-01 00:16:48                1            1.0           1
# 1   2015-01-01 00:24:20                1            0.9           1
# 2   2015-01-01 00:41:06                1            3.5           1
# 3   2015-01-01 00:53:20                1            2.1           1
# 4   2015-01-01 01:05:24                1            1.0           1
#
#   store_and_fwd_flag  PULocationID  ...  payment_type  fare_amount  extra  \
# 0                  N            41  ...             1          5.7    0.5
# 1                  N           166  ...             3          6.0    0.5
# 2                  N           238  ...             1         13.2    0.5
# 3                  N           162  ...             1          8.2    0.5
# 4                  N           236  ...             3          6.0    0.5
#
#    mta_tax  tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0      0.5        1.40           0.0                    0.0          8.40
# 1      0.5        0.00           0.0                    0.0          7.30
# 2      0.5        2.90           0.0                    0.0         17.40
# 3      0.5        2.37           0.0                    0.0         11.87
# 4      0.5        0.00           0.0                    0.0          7.30
#
#    congestion_surcharge  airport_fee
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Reading with pandas

# %% [markdown]
# #### Reading with Modin Pandas

# %%
start = time.time()

modin_df = pd.read_csv(dataset_url, parse_dates=["tpep_pickup_datetime", "tpep_dropoff_datetime"], quoting=3)

end = time.time()
modin_duration = end - start
print("Time to read with Modin: {} seconds".format(round(modin_duration, 3)))

print("Modin is {}x faster than pandas at `read_csv`!".format(round(pandas_duration / modin_duration, 2)))
# Out:
# Time to read with Modin: 4.614 seconds
# Modin is 1.05x faster than pandas at `read_csv`!

# %%
modin_df.shape
# Out:
# (1933507, 21)

# %%
modin_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  VendorID tpep_pickup_datetime  \
# 0             0           0         1  2015-01-01 00:11:33
# 1             1           1         1  2015-01-01 00:18:24
# 2             2           2         1  2015-01-01 00:26:19
# 3             3           3         1  2015-01-01 00:45:26
# 4             4           4         1  2015-01-01 00:59:21
#
#   tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0   2015-01-01 00:16:48                1            1.0           1
# 1   2015-01-01 00:24:20                1            0.9           1
# 2   2015-01-01 00:41:06                1            3.5           1
# 3   2015-01-01 00:53:20                1            2.1           1
# 4   2015-01-01 01:05:24                1            1.0           1
#
#   store_and_fwd_flag  PULocationID  ...  payment_type  fare_amount  extra  \
# 0                  N            41  ...             1          5.7    0.5
# 1                  N           166  ...             3          6.0    0.5
# 2                  N           238  ...             1         13.2    0.5
# 3                  N           162  ...             1          8.2    0.5
# 4                  N           236  ...             3          6.0    0.5
#
#    mta_tax  tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0      0.5        1.40           0.0                    0.0          8.40
# 1      0.5        0.00           0.0                    0.0          7.30
# 2      0.5        2.90           0.0                    0.0         17.40
# 3      0.5        2.37           0.0                    0.0         11.87
# 4      0.5        0.00           0.0                    0.0          7.30
#
#    congestion_surcharge  airport_fee
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN
#
# [5 rows x 21 columns]

# %%
# Now import modin
import modin.pandas as pd
import pandas
import time

import cmlextensions_custom.src.cmlextensions.ray_cluster as rc

import os

import cmlapi
import json
from pprint import pprint

# %%
# cluster = rc.RayCluster(num_workers=3)
# cluster.init()
# cluster = rc.RayCluster( num_workers=2,
#                          worker_cpu=8, worker_memory=16, worker_nvidia_gpu=0, 
#                          head_cpu=2, head_memory=16, head_nvidia_gpu=0
#                        )
# cluster.init()
cluster = rc.RayCluster(num_workers=3, worker_memory=12,head_memory=12)
cluster.init()
# Out:
# Starting ray head...
# Starting 3 ray workers...
# Could not start 3 requested ray workers.
#
# Could not start some of the ray workloads. Ensure ray is able to run in your environment and you have the resources in your CML workspace to provision the specified amount of ray workloads.
# Set a longer timeout period if your CML workspace needs time to scale.
# Shutting down Ray cluster..

# %%
# # Set MODIN_MEMORY to half of your total RAM (in bytes) - adjust based on your setup
# os.environ["MODIN_MEMORY"] = str(16 * 1024 * 1024 * 1024)  # Example for 16 GB

# # Set RAY_OBJECT_STORE_SIZE to a lower value if needed
# os.environ["RAY_OBJECT_STORE_SIZE"] = str(8 * 1024 * 1024 * 1024)  # Example for 8 GB

# %%
import ray
ray.init(address=cluster.get_client_url())
# Out:
# ClientContext(dashboard_url='', python_version='3.10.13', ray_version='2.6.0', ray_commit='0db82e31e249eac614f7c8e7da1c4f8f05c9064a', protocol_version='2023-06-27', _num_clients=1, _context_to_restore=<ray.util.client._ClientContext object at 0x7f5f569fce20>)

# %%
# This may take a few minutes to download
import urllib.request
dataset_url = "https://modin-datasets.intel.com/testing/yellow_tripdata_2015-01.csv"
urllib.request.urlretrieve(dataset_url, "taxi.csv")
# Out:
# ('taxi.csv', <http.client.HTTPMessage at 0x7f5f56e13c10>)

# %% [markdown]
# #### Reading with pandas

# %%
# Pandas loading time:
start = time.time()

pandas_df = pandas.read_csv(dataset_url, parse_dates=["tpep_pickup_datetime", "tpep_dropoff_datetime"], quoting=3)

end = time.time()
pandas_duration = end - start
print("Time to read with pandas: {} seconds".format(round(pandas_duration, 3)))
# Out:
# Time to read with pandas: 4.854 seconds

# %% [markdown]
# #### Reading with Modin Pandas

# %%
start = time.time()

modin_df = pd.read_csv(dataset_url, parse_dates=["tpep_pickup_datetime", "tpep_dropoff_datetime"], quoting=3)

end = time.time()
modin_duration = end - start
print("Time to read with Modin: {} seconds".format(round(modin_duration, 3)))

print("Modin is {}x faster than pandas at `read_csv`!".format(round(pandas_duration / modin_duration, 2)))
# Out:
# Time to read with Modin: 4.614 seconds
# Modin is 1.05x faster than pandas at `read_csv`!

# %%
modin_df.shape
# Out:
# (1933507, 21)

# %%
modin_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  VendorID tpep_pickup_datetime  \
# 0             0           0         1  2015-01-01 00:11:33
# 1             1           1         1  2015-01-01 00:18:24
# 2             2           2         1  2015-01-01 00:26:19
# 3             3           3         1  2015-01-01 00:45:26
# 4             4           4         1  2015-01-01 00:59:21
#
#   tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0   2015-01-01 00:16:48                1            1.0           1
# 1   2015-01-01 00:24:20                1            0.9           1
# 2   2015-01-01 00:41:06                1            3.5           1
# 3   2015-01-01 00:53:20                1            2.1           1
# 4   2015-01-01 01:05:24                1            1.0           1
#
#   store_and_fwd_flag  PULocationID  ...  payment_type  fare_amount  extra  \
# 0                  N            41  ...             1          5.7    0.5
# 1                  N           166  ...             3          6.0    0.5
# 2                  N           238  ...             1         13.2    0.5
# 3                  N           162  ...             1          8.2    0.5
# 4                  N           236  ...             3          6.0    0.5
#
#    mta_tax  tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0      0.5        1.40           0.0                    0.0          8.40
# 1      0.5        0.00           0.0                    0.0          7.30
# 2      0.5        2.90           0.0                    0.0         17.40
# 3      0.5        2.37           0.0                    0.0         11.87
# 4      0.5        0.00           0.0                    0.0          7.30
#
#    congestion_surcharge  airport_fee
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN
#
# [5 rows x 21 columns]

# %%
# shm_size = os.statvfs('/dev/shm').f_frsize * os.statvfs('/dev/shm').f_bavail
# print(f"Available /dev/shm size: {shm_size / 1024 / 1024:.2f} MB")

# %%
data_trans = pd.read_csv("data/transactions.csv")
# Out:
# ---------------------------------------------------------------------------
# RayTaskError(TypeError)                   Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 data_trans = pd.read_csv("data/transactions.csv")
#
# File ~/.local/lib/python3.10/site-packages/modin/utils.py:591, in expanduser_path_arg.<locals>.decorator.<locals>.wrapped(*args, **kw)
#     589     elif isinstance(patharg, Path):
#     590         params.arguments[argname] = patharg.expanduser()
# --> 591     return func(*params.args, **params.kwargs)
#     592 return func(*args, **kw)
#
# File ~/.local/lib/python3.10/site-packages/modin/logging/logger_decorator.py:144, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     129 """
#     130 Compute function with logging if Modin logging is enabled.
#     131
#    (...)
#     141 Any
#     142 """
#     143 if LogMode.get() == "disable":
# --> 144     return obj(*args, **kwargs)
#     146 logger = get_logger()
#     147 logger.log(log_level, start_line)
#
# File ~/.local/lib/python3.10/site-packages/modin/pandas/io.py:226, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     224 _, _, _, f_locals = inspect.getargvalues(inspect.currentframe())
#     225 kwargs = {k: v for k, v in f_locals.items() if k in _pd_read_csv_signature}
# --> 226 return _read(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/modin/pandas/io.py:116, in _read(**kwargs)
#     113 from modin.core.execution.dispatching.factories.dispatcher import FactoryDispatcher
#     115 squeeze = kwargs.pop("squeeze", False)
# --> 116 pd_obj = FactoryDispatcher.read_csv(**kwargs)
#     117 # This happens when `read_csv` returns a TextFileReader object for iterating through
#     118 if isinstance(pd_obj, TextFileReader):
#
# File ~/.local/lib/python3.10/site-packages/modin/core/execution/dispatching/factories/dispatcher.py:207, in FactoryDispatcher.read_csv(cls, **kwargs)
#     204 @classmethod
#     205 @_inherit_docstrings(factories.BaseFactory._read_csv)
#     206 def read_csv(cls, **kwargs):
# --> 207     return cls.get_factory()._read_csv(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/modin/core/execution/dispatching/factories/factories.py:267, in BaseFactory._read_csv(cls, **kwargs)
#     259 @classmethod
#     260 @doc(
#     261     _doc_io_method_template,
#    (...)
#     265 )
#     266 def _read_csv(cls, **kwargs):
# --> 267     return cls.io_cls.read_csv(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/modin/logging/logger_decorator.py:144, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     129 """
#     130 Compute function with logging if Modin logging is enabled.
#     131
#    (...)
#     141 Any
#     142 """
#     143 if LogMode.get() == "disable":
# --> 144     return obj(*args, **kwargs)
#     146 logger = get_logger()
#     147 logger.log(log_level, start_line)
#
# File ~/.local/lib/python3.10/site-packages/modin/core/io/file_dispatcher.py:165, in FileDispatcher.read(cls, *args, **kwargs)
#     163     return cls.single_worker_read(fname, *args, reason=str(err), **kwargs)
#     164 # TextFileReader can also be returned from `_read`.
# --> 165 if not AsyncReadMode.get() and hasattr(query_compiler, "dtypes"):
#     166     # at the moment it is not possible to use `wait_partitions` function;
#     167     # in a situation where the reading function is called in a row with the
#     168     # same parameters, `wait_partitions` considers that we have waited for
#     169     # the end of remote calculations, however, when trying to materialize the
#     170     # received data, it is clear that the calculations have not yet ended.
#     171     # for example, `test_io_exp.py::test_read_evaluated_dict` is failed because of that.
#     172     # see #5944 for details
#     173     _ = query_compiler.dtypes
#     174 return query_compiler
#
# File ~/.local/lib/python3.10/site-packages/modin/core/storage_formats/pandas/query_compiler.py:329, in PandasQueryCompiler.dtypes(self)
#     327 @property
#     328 def dtypes(self) -> pandas.Series:
# --> 329     return self._modin_frame.dtypes
#
# File ~/.local/lib/python3.10/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:424, in PandasDataframe.dtypes(self)
#     415 """
#     416 Compute the data types if they are not cached.
#     417
#    (...)
#     421     A pandas Series containing the data types for this dataframe.
#     422 """
#     423 if self.has_dtypes_cache:
# --> 424     dtypes = self._dtypes.get()
#     425 else:
#     426     dtypes = self._compute_dtypes()
#
# File ~/.local/lib/python3.10/site-packages/modin/core/dataframe/pandas/metadata/dtypes.py:924, in ModinDtypes.get(self)
#     922 if not self.is_materialized:
#     923     if callable(self._value):
# --> 924         self._value = self._value()
#     925         if self._value is None:
#     926             self._value = pandas.Series([])
#
# File ~/.local/lib/python3.10/site-packages/modin/core/io/text/text_file_dispatcher.py:946, in TextFileDispatcher._get_new_qc.<locals>.<lambda>()
#     904 """
#     905 Get new query compiler from data received from workers.
#     906
#    (...)
#     934     New query compiler, created from `new_frame`.
#     935 """
#     936 partition_ids = cls.build_partition(
#     937     partition_ids, [None] * len(index_ids), column_widths
#     938 )
#     940 new_frame = cls.frame_cls(
#     941     partition_ids,
#     942     lambda: cls._define_index(index_ids, index_name),
#     943     column_names,
#     944     None,
#     945     column_widths,
# --> 946     dtypes=lambda: cls.get_dtypes(dtypes_ids, column_names),
#     947 )
#     948 new_query_compiler = cls.query_compiler_cls(new_frame)
#     949 skipfooter = kwargs.get("skipfooter", None)
#
# File ~/.local/lib/python3.10/site-packages/modin/logging/logger_decorator.py:144, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     129 """
#     130 Compute function with logging if Modin logging is enabled.
#     131
#    (...)
#     141 Any
#     142 """
#     143 if LogMode.get() == "disable":
# --> 144     return obj(*args, **kwargs)
#     146 logger = get_logger()
#     147 logger.log(log_level, start_line)
#
# File ~/.local/lib/python3.10/site-packages/modin/core/storage_formats/pandas/parsers.py:257, in PandasParser.get_dtypes(cls, dtypes_ids, columns)
#     254     return None
#     255 # each element in `partitions_dtypes` is a Series, where column names are
#     256 # used as index and types of columns for different partitions are used as values
# --> 257 partitions_dtypes = cls.materialize(dtypes_ids)
#     258 if all([len(dtype) == 0 for dtype in partitions_dtypes]):
#     259     return None
#
# File ~/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py:139, in RayWrapper.materialize(cls, obj_id)
#     136     return ray.get(obj_id) if isinstance(obj_id, ray.ObjectRef) else obj_id
#     138 if all(isinstance(obj, ray.ObjectRef) for obj in obj_id):
# --> 139     return ray.get(obj_id)
#     141 ids = {}
#     142 result = []
#
# File ~/.local/lib/python3.10/site-packages/ray/_private/auto_init_hook.py:24, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      21 @wraps(fn)
#      22 def auto_init_wrapper(*args, **kwargs):
#      23     auto_init_ray()
# ---> 24     return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ray/_private/client_mode_hook.py:102, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#      98 if client_mode_should_convert():
#      99     # Legacy code
#     100     # we only convert init function if RAY_CLIENT_MODE=1
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
# --> 102         return getattr(ray, func.__name__)(*args, **kwargs)
#     103 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ray/util/client/api.py:42, in _ClientAPI.get(self, vals, timeout)
#      35 def get(self, vals, *, timeout=None):
#      36     """get is the hook stub passed on to replace `ray.get`
#      37
#      38     Args:
#      39         vals: [Client]ObjectRef or list of these refs to retrieve.
#      40         timeout: Optional timeout in milliseconds
#      41     """
# ---> 42     return self.worker.get(vals, timeout=timeout)
#
# File ~/.local/lib/python3.10/site-packages/ray/util/client/worker.py:434, in Worker.get(self, vals, timeout)
#     432     op_timeout = max_blocking_operation_time
#     433 try:
# --> 434     res = self._get(to_get, op_timeout)
#     435     break
#     436 except GetTimeoutError:
#
# File ~/.local/lib/python3.10/site-packages/ray/util/client/worker.py:462, in Worker._get(self, ref, timeout)
#     460         logger.exception("Failed to deserialize {}".format(chunk.error))
#     461         raise
# --> 462     raise err
#     463 if chunk.total_size > OBJECT_TRANSFER_WARNING_SIZE and log_once(
#     464     "client_object_transfer_size_warning"
#     465 ):
#     466     size_gb = chunk.total_size / 2**30
#
# RayTaskError(TypeError): ray::_deploy_ray_func() (pid=432, ip=100.100.175.137)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable

# %%
# Out:
# ---------------------------------------------------------------------------
# RayTaskError(TypeError)                   Traceback (most recent call last)
# Cell In[24], line 3
#       1 start = time.time()
# ----> 3 modin_df = pd.read_csv(dataset_url, parse_dates=["tpep_pickup_datetime", "tpep_dropoff_datetime"], quoting=3)
#       5 end = time.time()
#       6 modin_duration = end - start
#
# File ~/.local/lib/python3.10/site-packages/modin/utils.py:591, in expanduser_path_arg.<locals>.decorator.<locals>.wrapped(*args, **kw)
#     589     elif isinstance(patharg, Path):
#     590         params.arguments[argname] = patharg.expanduser()
# --> 591     return func(*params.args, **params.kwargs)
#     592 return func(*args, **kw)
#
# File ~/.local/lib/python3.10/site-packages/modin/logging/logger_decorator.py:144, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     129 """
#     130 Compute function with logging if Modin logging is enabled.
#     131
#    (...)
#     141 Any
#     142 """
#     143 if LogMode.get() == "disable":
# --> 144     return obj(*args, **kwargs)
#     146 logger = get_logger()
#     147 logger.log(log_level, start_line)
#
# File ~/.local/lib/python3.10/site-packages/modin/pandas/io.py:226, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     224 _, _, _, f_locals = inspect.getargvalues(inspect.currentframe())
#     225 kwargs = {k: v for k, v in f_locals.items() if k in _pd_read_csv_signature}
# --> 226 return _read(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/modin/pandas/io.py:116, in _read(**kwargs)
#     113 from modin.core.execution.dispatching.factories.dispatcher import FactoryDispatcher
#     115 squeeze = kwargs.pop("squeeze", False)
# --> 116 pd_obj = FactoryDispatcher.read_csv(**kwargs)
#     117 # This happens when `read_csv` returns a TextFileReader object for iterating through
#     118 if isinstance(pd_obj, TextFileReader):
#
# File ~/.local/lib/python3.10/site-packages/modin/core/execution/dispatching/factories/dispatcher.py:207, in FactoryDispatcher.read_csv(cls, **kwargs)
#     204 @classmethod
#     205 @_inherit_docstrings(factories.BaseFactory._read_csv)
#     206 def read_csv(cls, **kwargs):
# --> 207     return cls.get_factory()._read_csv(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/modin/core/execution/dispatching/factories/factories.py:267, in BaseFactory._read_csv(cls, **kwargs)
#     259 @classmethod
#     260 @doc(
#     261     _doc_io_method_template,
#    (...)
#     265 )
#     266 def _read_csv(cls, **kwargs):
# --> 267     return cls.io_cls.read_csv(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/modin/logging/logger_decorator.py:144, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     129 """
#     130 Compute function with logging if Modin logging is enabled.
#     131
#    (...)
#     141 Any
#     142 """
#     143 if LogMode.get() == "disable":
# --> 144     return obj(*args, **kwargs)
#     146 logger = get_logger()
#     147 logger.log(log_level, start_line)
#
# File ~/.local/lib/python3.10/site-packages/modin/core/io/file_dispatcher.py:165, in FileDispatcher.read(cls, *args, **kwargs)
#     163     return cls.single_worker_read(fname, *args, reason=str(err), **kwargs)
#     164 # TextFileReader can also be returned from `_read`.
# --> 165 if not AsyncReadMode.get() and hasattr(query_compiler, "dtypes"):
#     166     # at the moment it is not possible to use `wait_partitions` function;
#     167     # in a situation where the reading function is called in a row with the
#     168     # same parameters, `wait_partitions` considers that we have waited for
#     169     # the end of remote calculations, however, when trying to materialize the
#     170     # received data, it is clear that the calculations have not yet ended.
#     171     # for example, `test_io_exp.py::test_read_evaluated_dict` is failed because of that.
#     172     # see #5944 for details
#     173     _ = query_compiler.dtypes
#     174 return query_compiler
#
# File ~/.local/lib/python3.10/site-packages/modin/core/storage_formats/pandas/query_compiler.py:329, in PandasQueryCompiler.dtypes(self)
#     327 @property
#     328 def dtypes(self) -> pandas.Series:
# --> 329     return self._modin_frame.dtypes
#
# File ~/.local/lib/python3.10/site-packages/modin/core/dataframe/pandas/dataframe/dataframe.py:424, in PandasDataframe.dtypes(self)
#     415 """
#     416 Compute the data types if they are not cached.
#     417
#    (...)
#     421     A pandas Series containing the data types for this dataframe.
#     422 """
#     423 if self.has_dtypes_cache:
# --> 424     dtypes = self._dtypes.get()
#     425 else:
#     426     dtypes = self._compute_dtypes()
#
# File ~/.local/lib/python3.10/site-packages/modin/core/dataframe/pandas/metadata/dtypes.py:924, in ModinDtypes.get(self)
#     922 if not self.is_materialized:
#     923     if callable(self._value):
# --> 924         self._value = self._value()
#     925         if self._value is None:
#     926             self._value = pandas.Series([])
#
# File ~/.local/lib/python3.10/site-packages/modin/core/io/text/text_file_dispatcher.py:946, in TextFileDispatcher._get_new_qc.<locals>.<lambda>()
#     904 """
#     905 Get new query compiler from data received from workers.
#     906
#    (...)
#     934     New query compiler, created from `new_frame`.
#     935 """
#     936 partition_ids = cls.build_partition(
#     937     partition_ids, [None] * len(index_ids), column_widths
#     938 )
#     940 new_frame = cls.frame_cls(
#     941     partition_ids,
#     942     lambda: cls._define_index(index_ids, index_name),
#     943     column_names,
#     944     None,
#     945     column_widths,
# --> 946     dtypes=lambda: cls.get_dtypes(dtypes_ids, column_names),
#     947 )
#     948 new_query_compiler = cls.query_compiler_cls(new_frame)
#     949 skipfooter = kwargs.get("skipfooter", None)
#
# File ~/.local/lib/python3.10/site-packages/modin/logging/logger_decorator.py:144, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     129 """
#     130 Compute function with logging if Modin logging is enabled.
#     131
#    (...)
#     141 Any
#     142 """
#     143 if LogMode.get() == "disable":
# --> 144     return obj(*args, **kwargs)
#     146 logger = get_logger()
#     147 logger.log(log_level, start_line)
#
# File ~/.local/lib/python3.10/site-packages/modin/core/storage_formats/pandas/parsers.py:257, in PandasParser.get_dtypes(cls, dtypes_ids, columns)
#     254     return None
#     255 # each element in `partitions_dtypes` is a Series, where column names are
#     256 # used as index and types of columns for different partitions are used as values
# --> 257 partitions_dtypes = cls.materialize(dtypes_ids)
#     258 if all([len(dtype) == 0 for dtype in partitions_dtypes]):
#     259     return None
#
# File ~/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py:139, in RayWrapper.materialize(cls, obj_id)
#     136     return ray.get(obj_id) if isinstance(obj_id, ray.ObjectRef) else obj_id
#     138 if all(isinstance(obj, ray.ObjectRef) for obj in obj_id):
# --> 139     return ray.get(obj_id)
#     141 ids = {}
#     142 result = []
#
# File ~/.local/lib/python3.10/site-packages/ray/_private/auto_init_hook.py:24, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      21 @wraps(fn)
#      22 def auto_init_wrapper(*args, **kwargs):
#      23     auto_init_ray()
# ---> 24     return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ray/_private/client_mode_hook.py:102, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#      98 if client_mode_should_convert():
#      99     # Legacy code
#     100     # we only convert init function if RAY_CLIENT_MODE=1
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
# --> 102         return getattr(ray, func.__name__)(*args, **kwargs)
#     103 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ray/util/client/api.py:42, in _ClientAPI.get(self, vals, timeout)
#      35 def get(self, vals, *, timeout=None):
#      36     """get is the hook stub passed on to replace `ray.get`
#      37
#      38     Args:
#      39         vals: [Client]ObjectRef or list of these refs to retrieve.
#      40         timeout: Optional timeout in milliseconds
#      41     """
# ---> 42     return self.worker.get(vals, timeout=timeout)
#
# File ~/.local/lib/python3.10/site-packages/ray/util/client/worker.py:434, in Worker.get(self, vals, timeout)
#     432     op_timeout = max_blocking_operation_time
#     433 try:
# --> 434     res = self._get(to_get, op_timeout)
#     435     break
#     436 except GetTimeoutError:
#
# File ~/.local/lib/python3.10/site-packages/ray/util/client/worker.py:462, in Worker._get(self, ref, timeout)
#     460         logger.exception("Failed to deserialize {}".format(chunk.error))
#     461         raise
# --> 462     raise err
#     463 if chunk.total_size > OBJECT_TRANSFER_WARNING_SIZE and log_once(
#     464     "client_object_transfer_size_warning"
#     465 ):
#     466     size_gb = chunk.total_size / 2**30
#
# RayTaskError(TypeError): ray::_deploy_ray_func() (pid=431, ip=100.100.175.137)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable

# %%
ray.shutdown()
cluster.terminate()
# Out:
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=432, ip=100.100.175.137)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=432, ip=100.100.175.137)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=432, ip=100.100.175.137)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=431, ip=100.100.175.137)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=431, ip=100.100.175.137)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=259, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=259, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=259, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=260, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=260, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=260, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=258, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=258, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=258, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=261, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=261, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=261, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=432, ip=100.100.175.137)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=432, ip=100.100.175.137)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=431, ip=100.100.175.137)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=431, ip=100.100.175.137)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=431, ip=100.100.175.137)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=261, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=261, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=261, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=258, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=258, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=258, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
# Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_deploy_ray_func() (pid=260, ip=100.100.155.72)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
#   File "/home/cdsw/.local/lib/python3.10/site-packages/modin/core/execution/ray/common/engine_wrapper.py", line 53, in _deploy_ray_func
#     result = func(*args, **kwargs)
# TypeError: 'str' object is not callable
